# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 1000)
var = 7
y = np.exp(-(np.power(x, 2)) / (2 * var)) / (np.power(2 * np.pi * var, 0.5))

plt.plot(x, y)
plt.show()
